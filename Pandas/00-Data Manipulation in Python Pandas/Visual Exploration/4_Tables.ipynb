# %% [markdown]
# ## Pandas styling for tables!
#
# What if instead of having a ton of data to bin, we simply have a 2D table in pandas?

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)), columns=[x for x in "ABCDEF"])
df
# Out:
#           A         B         C         D         E         F
# 0 -1.601996 -0.915532 -0.251335  0.493483  0.230211  0.850075
# 1  1.249973 -0.265701  0.232081 -1.398890 -1.851947 -0.568343
# 2  2.033437  0.301444 -2.274119 -1.607131 -0.012862 -0.611850
# 3 -0.431450 -1.088948  1.232131 -0.094957  0.637819 -0.504826
# 4 -0.080845 -1.102016 -0.983307  0.087248 -1.833660  0.264486
# 5  0.000935 -0.913260 -0.811381  1.458980 -1.379306  1.086732

# %%
# Show red while negative
def neg_red(x):
    return f"color: {'red' if x < 0 else 'green'}"
df.style.applymap(neg_red)
# Out:
# <style type="text/css">
# #T_04365_row0_col0, #T_04365_row0_col1, #T_04365_row0_col2, #T_04365_row1_col1, #T_04365_row1_col3, #T_04365_row1_col4, #T_04365_row1_col5, #T_04365_row2_col2, #T_04365_row2_col3, #T_04365_row2_col4, #T_04365_row2_col5, #T_04365_row3_col0, #T_04365_row3_col1, #T_04365_row3_col3, #T_04365_row3_col5, #T_04365_row4_col0, #T_04365_row4_col1, #T_04365_row4_col2, #T_04365_row4_col4, #T_04365_row5_col1, #T_04365_row5_col2, #T_04365_row5_col4 {
#   color: red;
# }
# #T_04365_row0_col3, #T_04365_row0_col4, #T_04365_row0_col5, #T_04365_row1_col0, #T_04365_row1_col2, #T_04365_row2_col0, #T_04365_row2_col1, #T_04365_row3_col2, #T_04365_row3_col4, #T_04365_row4_col3, #T_04365_row4_col5, #T_04365_row5_col0, #T_04365_row5_col3, #T_04365_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_04365">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04365_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_04365_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_04365_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_04365_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_04365_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_04365_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04365_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04365_row0_col0" class="data row0 col0" >-1.601996</td>
#       <td id="T_04365_row0_col1" class="data row0 col1" >-0.915532</td>
#       <td id="T_04365_row0_col2" class="data row0 col2" >-0.251335</td>
#       <td id="T_04365_row0_col3" class="data row0 col3" >0.493483</td>
#       <td id="T_04365_row0_col4" class="data row0 col4" >0.230211</td>
#       <td id="T_04365_row0_col5" class="data row0 col5" >0.850075</td>
#     </tr>
#     <tr>
#       <th id="T_04365_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04365_row1_col0" class="data row1 col0" >1.249973</td>
#       <td id="T_04365_row1_col1" class="data row1 col1" >-0.265701</td>
#       <td id="T_04365_row1_col2" class="data row1 col2" >0.232081</td>
#       <td id="T_04365_row1_col3" class="data row1 col3" >-1.398890</td>
#       <td id="T_04365_row1_col4" class="data row1 col4" >-1.851947</td>
#       <td id="T_04365_row1_col5" class="data row1 col5" >-0.568343</td>
#     </tr>
#     <tr>
#       <th id="T_04365_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04365_row2_col0" class="data row2 col0" >2.033437</td>
#       <td id="T_04365_row2_col1" class="data row2 col1" >0.301444</td>
#       <td id="T_04365_row2_col2" class="data row2 col2" >-2.274119</td>
#       <td id="T_04365_row2_col3" class="data row2 col3" >-1.607131</td>
#       <td id="T_04365_row2_col4" class="data row2 col4" >-0.012862</td>
#       <td id="T_04365_row2_col5" class="data row2 col5" >-0.611850</td>
#     </tr>
#     <tr>
#       <th id="T_04365_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04365_row3_col0" class="data row3 col0" >-0.431450</td>
#       <td id="T_04365_row3_col1" class="data row3 col1" >-1.088948</td>
#       <td id="T_04365_row3_col2" class="data row3 col2" >1.232131</td>
#       <td id="T_04365_row3_col3" class="data row3 col3" >-0.094957</td>
#       <td id="T_04365_row3_col4" class="data row3 col4" >0.637819</td>
#       <td id="T_04365_row3_col5" class="data row3 col5" >-0.504826</td>
#     </tr>
#     <tr>
#       <th id="T_04365_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04365_row4_col0" class="data row4 col0" >-0.080845</td>
#       <td id="T_04365_row4_col1" class="data row4 col1" >-1.102016</td>
#       <td id="T_04365_row4_col2" class="data row4 col2" >-0.983307</td>
#       <td id="T_04365_row4_col3" class="data row4 col3" >0.087248</td>
#       <td id="T_04365_row4_col4" class="data row4 col4" >-1.833660</td>
#       <td id="T_04365_row4_col5" class="data row4 col5" >0.264486</td>
#     </tr>
#     <tr>
#       <th id="T_04365_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04365_row5_col0" class="data row5 col0" >0.000935</td>
#       <td id="T_04365_row5_col1" class="data row5 col1" >-0.913260</td>
#       <td id="T_04365_row5_col2" class="data row5 col2" >-0.811381</td>
#       <td id="T_04365_row5_col3" class="data row5 col3" >1.458980</td>
#       <td id="T_04365_row5_col4" class="data row5 col4" >-1.379306</td>
#       <td id="T_04365_row5_col5" class="data row5 col5" >1.086732</td>
#     </tr>
#   </tbody>
# </table>

# %%
# highlight max value
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max
#df.style.apply(gold_max, axis=None)
df.style.apply(gold_max, axis=None)
# Out:
# <style type="text/css">
# #T_70b73_row2_col0 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_70b73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70b73_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_70b73_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_70b73_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_70b73_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_70b73_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_70b73_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70b73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70b73_row0_col0" class="data row0 col0" >-1.601996</td>
#       <td id="T_70b73_row0_col1" class="data row0 col1" >-0.915532</td>
#       <td id="T_70b73_row0_col2" class="data row0 col2" >-0.251335</td>
#       <td id="T_70b73_row0_col3" class="data row0 col3" >0.493483</td>
#       <td id="T_70b73_row0_col4" class="data row0 col4" >0.230211</td>
#       <td id="T_70b73_row0_col5" class="data row0 col5" >0.850075</td>
#     </tr>
#     <tr>
#       <th id="T_70b73_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70b73_row1_col0" class="data row1 col0" >1.249973</td>
#       <td id="T_70b73_row1_col1" class="data row1 col1" >-0.265701</td>
#       <td id="T_70b73_row1_col2" class="data row1 col2" >0.232081</td>
#       <td id="T_70b73_row1_col3" class="data row1 col3" >-1.398890</td>
#       <td id="T_70b73_row1_col4" class="data row1 col4" >-1.851947</td>
#       <td id="T_70b73_row1_col5" class="data row1 col5" >-0.568343</td>
#     </tr>
#     <tr>
#       <th id="T_70b73_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70b73_row2_col0" class="data row2 col0" >2.033437</td>
#       <td id="T_70b73_row2_col1" class="data row2 col1" >0.301444</td>
#       <td id="T_70b73_row2_col2" class="data row2 col2" >-2.274119</td>
#       <td id="T_70b73_row2_col3" class="data row2 col3" >-1.607131</td>
#       <td id="T_70b73_row2_col4" class="data row2 col4" >-0.012862</td>
#       <td id="T_70b73_row2_col5" class="data row2 col5" >-0.611850</td>
#     </tr>
#     <tr>
#       <th id="T_70b73_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70b73_row3_col0" class="data row3 col0" >-0.431450</td>
#       <td id="T_70b73_row3_col1" class="data row3 col1" >-1.088948</td>
#       <td id="T_70b73_row3_col2" class="data row3 col2" >1.232131</td>
#       <td id="T_70b73_row3_col3" class="data row3 col3" >-0.094957</td>
#       <td id="T_70b73_row3_col4" class="data row3 col4" >0.637819</td>
#       <td id="T_70b73_row3_col5" class="data row3 col5" >-0.504826</td>
#     </tr>
#     <tr>
#       <th id="T_70b73_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_70b73_row4_col0" class="data row4 col0" >-0.080845</td>
#       <td id="T_70b73_row4_col1" class="data row4 col1" >-1.102016</td>
#       <td id="T_70b73_row4_col2" class="data row4 col2" >-0.983307</td>
#       <td id="T_70b73_row4_col3" class="data row4 col3" >0.087248</td>
#       <td id="T_70b73_row4_col4" class="data row4 col4" >-1.833660</td>
#       <td id="T_70b73_row4_col5" class="data row4 col5" >0.264486</td>
#     </tr>
#     <tr>
#       <th id="T_70b73_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_70b73_row5_col0" class="data row5 col0" >0.000935</td>
#       <td id="T_70b73_row5_col1" class="data row5 col1" >-0.913260</td>
#       <td id="T_70b73_row5_col2" class="data row5 col2" >-0.811381</td>
#       <td id="T_70b73_row5_col3" class="data row5 col3" >1.458980</td>
#       <td id="T_70b73_row5_col4" class="data row5 col4" >-1.379306</td>
#       <td id="T_70b73_row5_col5" class="data row5 col5" >1.086732</td>
#     </tr>
#   </tbody>
# </table>

# %%
# highlight max value in rows
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True: "background-color: #c78f2e", False: ""}
    is_max = (xs == m).replace(color)
    return is_max
#df.style.apply(gold_max, axis=None)
df.style.apply(gold_max, axis=1)
# Out:
# <style type="text/css">
# #T_b84fb_row0_col5, #T_b84fb_row1_col0, #T_b84fb_row2_col0, #T_b84fb_row3_col2, #T_b84fb_row4_col5, #T_b84fb_row5_col3 {
#   background-color: #c78f2e;
# }
# </style>
# <table id="T_b84fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b84fb_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_b84fb_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_b84fb_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_b84fb_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_b84fb_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_b84fb_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b84fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b84fb_row0_col0" class="data row0 col0" >-1.601996</td>
#       <td id="T_b84fb_row0_col1" class="data row0 col1" >-0.915532</td>
#       <td id="T_b84fb_row0_col2" class="data row0 col2" >-0.251335</td>
#       <td id="T_b84fb_row0_col3" class="data row0 col3" >0.493483</td>
#       <td id="T_b84fb_row0_col4" class="data row0 col4" >0.230211</td>
#       <td id="T_b84fb_row0_col5" class="data row0 col5" >0.850075</td>
#     </tr>
#     <tr>
#       <th id="T_b84fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b84fb_row1_col0" class="data row1 col0" >1.249973</td>
#       <td id="T_b84fb_row1_col1" class="data row1 col1" >-0.265701</td>
#       <td id="T_b84fb_row1_col2" class="data row1 col2" >0.232081</td>
#       <td id="T_b84fb_row1_col3" class="data row1 col3" >-1.398890</td>
#       <td id="T_b84fb_row1_col4" class="data row1 col4" >-1.851947</td>
#       <td id="T_b84fb_row1_col5" class="data row1 col5" >-0.568343</td>
#     </tr>
#     <tr>
#       <th id="T_b84fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b84fb_row2_col0" class="data row2 col0" >2.033437</td>
#       <td id="T_b84fb_row2_col1" class="data row2 col1" >0.301444</td>
#       <td id="T_b84fb_row2_col2" class="data row2 col2" >-2.274119</td>
#       <td id="T_b84fb_row2_col3" class="data row2 col3" >-1.607131</td>
#       <td id="T_b84fb_row2_col4" class="data row2 col4" >-0.012862</td>
#       <td id="T_b84fb_row2_col5" class="data row2 col5" >-0.611850</td>
#     </tr>
#     <tr>
#       <th id="T_b84fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b84fb_row3_col0" class="data row3 col0" >-0.431450</td>
#       <td id="T_b84fb_row3_col1" class="data row3 col1" >-1.088948</td>
#       <td id="T_b84fb_row3_col2" class="data row3 col2" >1.232131</td>
#       <td id="T_b84fb_row3_col3" class="data row3 col3" >-0.094957</td>
#       <td id="T_b84fb_row3_col4" class="data row3 col4" >0.637819</td>
#       <td id="T_b84fb_row3_col5" class="data row3 col5" >-0.504826</td>
#     </tr>
#     <tr>
#       <th id="T_b84fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b84fb_row4_col0" class="data row4 col0" >-0.080845</td>
#       <td id="T_b84fb_row4_col1" class="data row4 col1" >-1.102016</td>
#       <td id="T_b84fb_row4_col2" class="data row4 col2" >-0.983307</td>
#       <td id="T_b84fb_row4_col3" class="data row4 col3" >0.087248</td>
#       <td id="T_b84fb_row4_col4" class="data row4 col4" >-1.833660</td>
#       <td id="T_b84fb_row4_col5" class="data row4 col5" >0.264486</td>
#     </tr>
#     <tr>
#       <th id="T_b84fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b84fb_row5_col0" class="data row5 col0" >0.000935</td>
#       <td id="T_b84fb_row5_col1" class="data row5 col1" >-0.913260</td>
#       <td id="T_b84fb_row5_col2" class="data row5 col2" >-0.811381</td>
#       <td id="T_b84fb_row5_col3" class="data row5 col3" >1.458980</td>
#       <td id="T_b84fb_row5_col4" class="data row5 col4" >-1.379306</td>
#       <td id="T_b84fb_row5_col5" class="data row5 col5" >1.086732</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.background_gradient(cmap="magma")
# Out:
# <style type="text/css">
# #T_d6ec7_row0_col0, #T_d6ec7_row1_col4, #T_d6ec7_row2_col2, #T_d6ec7_row2_col3, #T_d6ec7_row2_col5, #T_d6ec7_row4_col1 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_d6ec7_row0_col1, #T_d6ec7_row5_col1 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_d6ec7_row0_col2 {
#   background-color: #d5446d;
#   color: #f1f1f1;
# }
# #T_d6ec7_row0_col3 {
#   background-color: #f4695c;
#   color: #f1f1f1;
# }
# #T_d6ec7_row0_col4 {
#   background-color: #feb27a;
#   color: #000000;
# }
# #T_d6ec7_row0_col5 {
#   background-color: #febd82;
#   color: #000000;
# }
# #T_d6ec7_row1_col0 {
#   background-color: #fd9869;
#   color: #000000;
# }
# #T_d6ec7_row1_col1 {
#   background-color: #dc4869;
#   color: #f1f1f1;
# }
# #T_d6ec7_row1_col2 {
#   background-color: #f8765c;
#   color: #f1f1f1;
# }
# #T_d6ec7_row1_col3 {
#   background-color: #0b0924;
#   color: #f1f1f1;
# }
# #T_d6ec7_row1_col5 {
#   background-color: #02020d;
#   color: #f1f1f1;
# }
# #T_d6ec7_row2_col0, #T_d6ec7_row2_col1, #T_d6ec7_row3_col2, #T_d6ec7_row3_col4, #T_d6ec7_row5_col3, #T_d6ec7_row5_col5 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_d6ec7_row2_col4 {
#   background-color: #fb835f;
#   color: #f1f1f1;
# }
# #T_d6ec7_row3_col0 {
#   background-color: #6d1d81;
#   color: #f1f1f1;
# }
# #T_d6ec7_row3_col1 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_d6ec7_row3_col3 {
#   background-color: #b3367a;
#   color: #f1f1f1;
# }
# #T_d6ec7_row3_col5 {
#   background-color: #0a0822;
#   color: #f1f1f1;
# }
# #T_d6ec7_row4_col0 {
#   background-color: #942c80;
#   color: #f1f1f1;
# }
# #T_d6ec7_row4_col2 {
#   background-color: #802582;
#   color: #f1f1f1;
# }
# #T_d6ec7_row4_col3 {
#   background-color: #cc3f71;
#   color: #f1f1f1;
# }
# #T_d6ec7_row4_col4 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_d6ec7_row4_col5 {
#   background-color: #bd3977;
#   color: #f1f1f1;
# }
# #T_d6ec7_row5_col0 {
#   background-color: #9c2e7f;
#   color: #f1f1f1;
# }
# #T_d6ec7_row5_col2 {
#   background-color: #932b80;
#   color: #f1f1f1;
# }
# #T_d6ec7_row5_col4 {
#   background-color: #36106b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d6ec7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6ec7_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d6ec7_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_d6ec7_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_d6ec7_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_d6ec7_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_d6ec7_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6ec7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6ec7_row0_col0" class="data row0 col0" >-1.601996</td>
#       <td id="T_d6ec7_row0_col1" class="data row0 col1" >-0.915532</td>
#       <td id="T_d6ec7_row0_col2" class="data row0 col2" >-0.251335</td>
#       <td id="T_d6ec7_row0_col3" class="data row0 col3" >0.493483</td>
#       <td id="T_d6ec7_row0_col4" class="data row0 col4" >0.230211</td>
#       <td id="T_d6ec7_row0_col5" class="data row0 col5" >0.850075</td>
#     </tr>
#     <tr>
#       <th id="T_d6ec7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6ec7_row1_col0" class="data row1 col0" >1.249973</td>
#       <td id="T_d6ec7_row1_col1" class="data row1 col1" >-0.265701</td>
#       <td id="T_d6ec7_row1_col2" class="data row1 col2" >0.232081</td>
#       <td id="T_d6ec7_row1_col3" class="data row1 col3" >-1.398890</td>
#       <td id="T_d6ec7_row1_col4" class="data row1 col4" >-1.851947</td>
#       <td id="T_d6ec7_row1_col5" class="data row1 col5" >-0.568343</td>
#     </tr>
#     <tr>
#       <th id="T_d6ec7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6ec7_row2_col0" class="data row2 col0" >2.033437</td>
#       <td id="T_d6ec7_row2_col1" class="data row2 col1" >0.301444</td>
#       <td id="T_d6ec7_row2_col2" class="data row2 col2" >-2.274119</td>
#       <td id="T_d6ec7_row2_col3" class="data row2 col3" >-1.607131</td>
#       <td id="T_d6ec7_row2_col4" class="data row2 col4" >-0.012862</td>
#       <td id="T_d6ec7_row2_col5" class="data row2 col5" >-0.611850</td>
#     </tr>
#     <tr>
#       <th id="T_d6ec7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6ec7_row3_col0" class="data row3 col0" >-0.431450</td>
#       <td id="T_d6ec7_row3_col1" class="data row3 col1" >-1.088948</td>
#       <td id="T_d6ec7_row3_col2" class="data row3 col2" >1.232131</td>
#       <td id="T_d6ec7_row3_col3" class="data row3 col3" >-0.094957</td>
#       <td id="T_d6ec7_row3_col4" class="data row3 col4" >0.637819</td>
#       <td id="T_d6ec7_row3_col5" class="data row3 col5" >-0.504826</td>
#     </tr>
#     <tr>
#       <th id="T_d6ec7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6ec7_row4_col0" class="data row4 col0" >-0.080845</td>
#       <td id="T_d6ec7_row4_col1" class="data row4 col1" >-1.102016</td>
#       <td id="T_d6ec7_row4_col2" class="data row4 col2" >-0.983307</td>
#       <td id="T_d6ec7_row4_col3" class="data row4 col3" >0.087248</td>
#       <td id="T_d6ec7_row4_col4" class="data row4 col4" >-1.833660</td>
#       <td id="T_d6ec7_row4_col5" class="data row4 col5" >0.264486</td>
#     </tr>
#     <tr>
#       <th id="T_d6ec7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d6ec7_row5_col0" class="data row5 col0" >0.000935</td>
#       <td id="T_d6ec7_row5_col1" class="data row5 col1" >-0.913260</td>
#       <td id="T_d6ec7_row5_col2" class="data row5 col2" >-0.811381</td>
#       <td id="T_d6ec7_row5_col3" class="data row5 col3" >1.458980</td>
#       <td id="T_d6ec7_row5_col4" class="data row5 col4" >-1.379306</td>
#       <td id="T_d6ec7_row5_col5" class="data row5 col5" >1.086732</td>
#     </tr>
#   </tbody>
# </table>

# %%
# the width of the bar plot is 90%, by default 100%. The representation for the value in the cell as to how big
# the bar plot is.
df.abs().style.bar(align="left", width=90)
# Out:
# <style type="text/css">
# #T_7fb83_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.9%, transparent 70.9%);
# }
# #T_7fb83_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.9%, transparent 69.9%);
# }
# #T_7fb83_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_7fb83_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.1%, transparent 24.1%);
# }
# #T_7fb83_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.6%, transparent 10.6%);
# }
# #T_7fb83_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 64.1%, transparent 64.1%);
# }
# #T_7fb83_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.3%, transparent 55.3%);
# }
# #T_7fb83_row1_col1, #T_7fb83_row1_col2, #T_7fb83_row2_col4, #T_7fb83_row4_col3, #T_7fb83_row4_col5, #T_7fb83_row5_col0 {
#   width: 10em;
# }
# #T_7fb83_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 77.7%, transparent 77.7%);
# }
# #T_7fb83_row1_col4, #T_7fb83_row2_col0, #T_7fb83_row2_col2, #T_7fb83_row2_col3, #T_7fb83_row4_col1, #T_7fb83_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.0%, transparent 90.0%);
# }
# #T_7fb83_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.3%, transparent 33.3%);
# }
# #T_7fb83_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.8%, transparent 3.8%);
# }
# #T_7fb83_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.0%, transparent 38.0%);
# }
# #T_7fb83_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.1%, transparent 19.1%);
# }
# #T_7fb83_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.6%, transparent 88.6%);
# }
# #T_7fb83_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.1%, transparent 44.1%);
# }
# #T_7fb83_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_7fb83_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 30.6%, transparent 30.6%);
# }
# #T_7fb83_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.3%, transparent 26.3%);
# }
# #T_7fb83_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.5%, transparent 3.5%);
# }
# #T_7fb83_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.1%, transparent 33.1%);
# }
# #T_7fb83_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.1%, transparent 89.1%);
# }
# #T_7fb83_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.7%, transparent 69.7%);
# }
# #T_7fb83_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.5%, transparent 25.5%);
# }
# #T_7fb83_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.2%, transparent 81.2%);
# }
# #T_7fb83_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.9%, transparent 66.9%);
# }
# </style>
# <table id="T_7fb83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fb83_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7fb83_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_7fb83_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_7fb83_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_7fb83_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_7fb83_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fb83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fb83_row0_col0" class="data row0 col0" >1.601996</td>
#       <td id="T_7fb83_row0_col1" class="data row0 col1" >0.915532</td>
#       <td id="T_7fb83_row0_col2" class="data row0 col2" >0.251335</td>
#       <td id="T_7fb83_row0_col3" class="data row0 col3" >0.493483</td>
#       <td id="T_7fb83_row0_col4" class="data row0 col4" >0.230211</td>
#       <td id="T_7fb83_row0_col5" class="data row0 col5" >0.850075</td>
#     </tr>
#     <tr>
#       <th id="T_7fb83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7fb83_row1_col0" class="data row1 col0" >1.249973</td>
#       <td id="T_7fb83_row1_col1" class="data row1 col1" >0.265701</td>
#       <td id="T_7fb83_row1_col2" class="data row1 col2" >0.232081</td>
#       <td id="T_7fb83_row1_col3" class="data row1 col3" >1.398890</td>
#       <td id="T_7fb83_row1_col4" class="data row1 col4" >1.851947</td>
#       <td id="T_7fb83_row1_col5" class="data row1 col5" >0.568343</td>
#     </tr>
#     <tr>
#       <th id="T_7fb83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7fb83_row2_col0" class="data row2 col0" >2.033437</td>
#       <td id="T_7fb83_row2_col1" class="data row2 col1" >0.301444</td>
#       <td id="T_7fb83_row2_col2" class="data row2 col2" >2.274119</td>
#       <td id="T_7fb83_row2_col3" class="data row2 col3" >1.607131</td>
#       <td id="T_7fb83_row2_col4" class="data row2 col4" >0.012862</td>
#       <td id="T_7fb83_row2_col5" class="data row2 col5" >0.611850</td>
#     </tr>
#     <tr>
#       <th id="T_7fb83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7fb83_row3_col0" class="data row3 col0" >0.431450</td>
#       <td id="T_7fb83_row3_col1" class="data row3 col1" >1.088948</td>
#       <td id="T_7fb83_row3_col2" class="data row3 col2" >1.232131</td>
#       <td id="T_7fb83_row3_col3" class="data row3 col3" >0.094957</td>
#       <td id="T_7fb83_row3_col4" class="data row3 col4" >0.637819</td>
#       <td id="T_7fb83_row3_col5" class="data row3 col5" >0.504826</td>
#     </tr>
#     <tr>
#       <th id="T_7fb83_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7fb83_row4_col0" class="data row4 col0" >0.080845</td>
#       <td id="T_7fb83_row4_col1" class="data row4 col1" >1.102016</td>
#       <td id="T_7fb83_row4_col2" class="data row4 col2" >0.983307</td>
#       <td id="T_7fb83_row4_col3" class="data row4 col3" >0.087248</td>
#       <td id="T_7fb83_row4_col4" class="data row4 col4" >1.833660</td>
#       <td id="T_7fb83_row4_col5" class="data row4 col5" >0.264486</td>
#     </tr>
#     <tr>
#       <th id="T_7fb83_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7fb83_row5_col0" class="data row5 col0" >0.000935</td>
#       <td id="T_7fb83_row5_col1" class="data row5 col1" >0.913260</td>
#       <td id="T_7fb83_row5_col2" class="data row5 col2" >0.811381</td>
#       <td id="T_7fb83_row5_col3" class="data row5 col3" >1.458980</td>
#       <td id="T_7fb83_row5_col4" class="data row5 col4" >1.379306</td>
#       <td id="T_7fb83_row5_col5" class="data row5 col5" >1.086732</td>
#     </tr>
#   </tbody>
# </table>

# %%
# make the bar plot if it goes right, as in a positive value green and if it goes left a negative
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align="mid", color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style type="text/css">
# #T_e0458 th {
#   text-align: center;
# }
# #T_e0458_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.3%, red 45.3%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.8%, transparent 51.8%);
# }
# #T_e0458_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.4%, transparent 57.4%);
# }
# #T_e0458_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 52.0%, transparent 52.0%);
# }
# #T_e0458_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 75.1%, transparent 75.1%);
# }
# #T_e0458_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 33.1%, red 33.1%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 83.7%, transparent 83.7%);
# }
# #T_e0458_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.9%, red 49.9%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 84.4%, transparent 84.4%);
# }
# #T_e0458_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 79.4%, transparent 79.4%);
# }
# #T_e0458_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 64.9%, transparent 64.9%);
# }
# #T_e0458_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.2%, red 44.2%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.9%, red 24.9%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 40.1%, red 40.1%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.2%, red 41.2%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 80.4%, transparent 80.4%);
# }
# #T_e0458_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 58.8%, transparent 58.8%);
# }
# #T_e0458_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 12.5%, red 12.5%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 64.6%, transparent 64.6%);
# }
# #T_e0458_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 50.7%, transparent 50.7%);
# }
# #T_e0458_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.3%, transparent 66.3%);
# }
# #T_e0458_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.2%, red 26.2%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.6%, red 22.6%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 73.0%, transparent 73.0%);
# }
# #T_e0458_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 50.8%, transparent 50.8%);
# }
# #T_e0458_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.8%, red 49.8%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 72.9%, transparent 72.9%);
# }
# #T_e0458_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 45.9%, red 45.9%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 81.1%, transparent 81.1%);
# }
# #T_e0458_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 57.5%, transparent 57.5%);
# }
# #T_e0458_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 62.7%, transparent 62.7%);
# }
# #T_e0458_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 100.0%, transparent 100.0%);
# }
# #T_e0458_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 79.1%, transparent 79.1%);
# }
# #T_e0458_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 78.8%, transparent 78.8%);
# }
# #T_e0458_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 34.9%, red 34.9%, red 50.0%, transparent 50.0%);
# }
# #T_e0458_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.2%, red 39.2%, red 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_e0458">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0458_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e0458_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e0458_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_e0458_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_e0458_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_e0458_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0458_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0458_row0_col0" class="data row0 col0" >-0.279794</td>
#       <td id="T_e0458_row0_col1" class="data row0 col1" >0.106343</td>
#       <td id="T_e0458_row0_col2" class="data row0 col2" >0.441139</td>
#       <td id="T_e0458_row0_col3" class="data row0 col3" >0.118343</td>
#       <td id="T_e0458_row0_col4" class="data row0 col4" >1.504255</td>
#       <td id="T_e0458_row0_col5" class="data row0 col5" >-1.016258</td>
#     </tr>
#     <tr>
#       <th id="T_e0458_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0458_row1_col0" class="data row1 col0" >2.023958</td>
#       <td id="T_e0458_row1_col1" class="data row1 col1" >-0.008636</td>
#       <td id="T_e0458_row1_col2" class="data row1 col2" >2.065981</td>
#       <td id="T_e0458_row1_col3" class="data row1 col3" >1.764868</td>
#       <td id="T_e0458_row1_col4" class="data row1 col4" >0.896542</td>
#       <td id="T_e0458_row1_col5" class="data row1 col5" >-0.350265</td>
#     </tr>
#     <tr>
#       <th id="T_e0458_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0458_row2_col0" class="data row2 col0" >-1.506138</td>
#       <td id="T_e0458_row2_col1" class="data row2 col1" >-0.595635</td>
#       <td id="T_e0458_row2_col2" class="data row2 col2" >-0.528182</td>
#       <td id="T_e0458_row2_col3" class="data row2 col3" >1.824362</td>
#       <td id="T_e0458_row2_col4" class="data row2 col4" >0.525632</td>
#       <td id="T_e0458_row2_col5" class="data row2 col5" >-2.251127</td>
#     </tr>
#     <tr>
#       <th id="T_e0458_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0458_row3_col0" class="data row3 col0" >0.874864</td>
#       <td id="T_e0458_row3_col1" class="data row3 col1" >0.042307</td>
#       <td id="T_e0458_row3_col2" class="data row3 col2" >0.980388</td>
#       <td id="T_e0458_row3_col3" class="data row3 col3" >-1.425931</td>
#       <td id="T_e0458_row3_col4" class="data row3 col4" >-1.641061</td>
#       <td id="T_e0458_row3_col5" class="data row3 col5" >1.382976</td>
#     </tr>
#     <tr>
#       <th id="T_e0458_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0458_row4_col0" class="data row4 col0" >0.048184</td>
#       <td id="T_e0458_row4_col1" class="data row4 col1" >-0.014093</td>
#       <td id="T_e0458_row4_col2" class="data row4 col2" >1.37

# %%
# highligh max as gold background. Negative number in red. Not good for presentation.
df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# <style type="text/css">
# #T_eb5e1_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.0%, transparent 22.0%);
#   color: red;
# }
# #T_eb5e1_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 6.6%, #d65f5f 6.6%, #d65f5f 39.3%, transparent 39.3%);
#   color: red;
# }
# #T_eb5e1_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 28.8%, #d65f5f 28.8%, #d65f5f 32.4%, transparent 32.4%);
#   color: red;
# }
# #T_eb5e1_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.2%, #d65f5f 26.2%, #d65f5f 34.3%, transparent 34.3%);
#   color: green;
# }
# #T_eb5e1_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.2%, #d65f5f 37.2%, #d65f5f 41.8%, transparent 41.8%);
#   color: green;
# }
# #T_eb5e1_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.0%, #d65f5f 18.0%, #d65f5f 43.0%, transparent 43.0%);
#   color: green;
# }
# #T_eb5e1_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.0%, #d65f5f 22.0%, #d65f5f 39.2%, transparent 39.2%);
#   color: green;
# }
# #T_eb5e1_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.8%, #d65f5f 29.8%, #d65f5f 39.3%, transparent 39.3%);
#   color: red;
# }
# #T_eb5e1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.4%, #d65f5f 32.4%, #d65f5f 35.7%, transparent 35.7%);
#   color: green;
# }
# #T_eb5e1_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.4%, #d65f5f 3.4%, #d65f5f 26.2%, transparent 26.2%);
#   color: red;
# }
# #T_eb5e1_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 37.2%, transparent 37.2%);
#   color: red;
# }
# #T_eb5e1_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 1.3%, #d65f5f 1.3%, #d65f5f 18.0%, transparent 18.0%);
#   color: red;
# }
# #T_eb5e1_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.0%, #d65f5f 22.0%, #d65f5f 50.0%, transparent 50.0%);
#   background-color: #c78f2e;
#   color: green;
# }
# #T_eb5e1_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 39.3%, #d65f5f 39.3%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_eb5e1_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.4%, transparent 32.4%);
#   color: red;
# }
# #T_eb5e1_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.2%, transparent 26.2%);
#   color: red;
# }
# #T_eb5e1_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 36.9%, #d65f5f 36.9%, #d65f5f 37.2%, transparent 37.2%);
#   color: red;
# }
# #T_eb5e1_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.0%, transparent 18.0%);
#   color: red;
# }
# #T_eb5e1_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.1%, #d65f5f 16.1%, #d65f5f 22.0%, transparent 22.0%);
#   color: red;
# }
# #T_eb5e1_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.5%, #d65f5f 0.5%, #d65f5f 39.3%, transparent 39.3%);
#   color: red;
# }
# #T_eb5e1_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 32.4%, #d65f5f 32.4%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_eb5e1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 24.7%, #d65f5f 24.7%, #d65f5f 26.2%, transparent 26.2%);
#   color: red;
# }
# #T_eb5e1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 37.2%, #d65f5f 37.2%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_eb5e1_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 3.2%, #d65f5f 3.2%, #d65f5f 18.0%, transparent 18.0%);
#   color: red;
# }
# #T_eb5e1_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.9%, #d65f5f 20.9%, #d65f5f 22.0%, transparent 22.0%);
#   color: red;
# }
# #T_eb5e1_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 39.3%, transparent 39.3%);
#   color: red;
# }
# #T_eb5e1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.4%, #d65f5f 18.4%, #d65f5f 32.4%, transparent 32.4%);
#   color: red;
# }
# #T_eb5e1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.2%, #d65f5f 26.2%, #d65f5f 27.6%, transparent 27.6%);
#   color: green;
# }
# #T_eb5e1_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.4%, #d65f5f 0.4%, #d65f5f 37.2%, transparent 37.2%);
#   color: red;
# }
# #T_eb5e1_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.0%, #d65f5f 18.0%, #d65f5f 25.8%, transparent 25.8%);
#   color: green;
# }
# #T_eb5e1_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 22.0%, #d65f5f 22.0%, #d65f5f 22.0%, transparent 22.0%);
#   color: green;
# }
# #T_eb5e1_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 6.7%, #d65f5f 6.7%, #d65f5f 39.3%, transparent 39.3%);
#   color: red;
# }
# #T_eb5e1_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.9%, #d65f5f 20.9%, #d65f5f 32.4%, transparent 32.4%);
#   color: red;
# }
# #T_eb5e1_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 26.2%, #d65f5f 26.2%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# #T_eb5e1_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 9.5%, #d65f5f 9.5%, #d65f5f 37.2%, transparent 37.2%);
#   color: red;
# }
# #T_eb5e1_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 18.0%, #d65f5f 18.0%, #d65f5f 50.0%, transparent 50.0%);
#   color: green;
# }
# </style>
# <table id="T_eb5e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb5e1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_eb5e1_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_eb5e1_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_eb5e1_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_eb5e1_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_eb5e1_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb5e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb5e1_row0_col0" class="data row0 col0" >-1.601996</td>
#       <td id="T_eb5e1_row0_col1" class="data row0 col1" >-0.915532</td>
#       <td id="T_eb5e1_row0_col2" class="data row0 col2" >-0.251335</td>
#       <td id="T_eb5e1_row0_col3" class="data row0 col3" >0.493483</td>
#       <td id="T_eb5e1_row0_col4" class="data row0 col4" >0.230211</td>
#       <td id="T_eb5e1_row0_col5" class="data row0 col5" >0.850075</td>
#     </tr>
#     <tr>
#       <th id="T_eb5e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb5e1_row1_col0" class="data row1 col0" >1.249973</td>
#       <td id="T_eb5e1_row1_col1" class="data row1 col1" >-0.265701</td>
#       <td id="T_eb5e1_row1_col2" class="data row1 col2" >0.232081</td>
#       <td id="T_eb5e1_row1_col3" class="data row1 col3" >-1.398890</td>
#       <td id="T_eb5e1_row1_col4" class="data row1 col4" >-1.851947</td>
#       <td id="T_eb5e1_row1_col5" class="data row1 col5" >-0.568343</td>
#     </tr>
#     <tr>
#       <th id="T_eb5e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb5e1_row2_col0" class="data row2 col0" >2.033437</td>
#       <td id="T_eb5e1_row2_col1" class="data row2 col1" >0.301444</td>
#       <td id="T_eb5e1_row2_col2" class="data row2 col2" >-2.274119</td>
#       <td id="T_eb5e1_row2_col3" class="data row2 col3" >-1.607131</td>
#       <td id="T_eb5e1_row2_col4" class="data row2 col4" >-0.012862</td>
#       <td id="T_eb5e1_row2_col5" class="data row2 col5" >-0.611850</td>
#     </tr>
#     <tr>
#       <th id="T_eb5e1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb5e1_row3_col0" class="data row3 col0" >-0.431450</td>
#       <td id="T_eb5e1_row3_col1" class="data row3 col1" >-1.088948</td>
#       <td id="T_eb5e1_row3_col2" class="data row3 col2" >1.232131</td>
#       <
