# %% [markdown]
# # SIMPLE LINEAR REGRESSION

# %% [markdown]
# ![Simple_Linear_Regression_Process.png](attachment:fce47bd2-9371-4597-96e3-84a2825d29d4.png)# PROBLEM STATEMENT

# %% [markdown]
# You own an ice cream business and you would like to create a model that could predict the daily revenue in dollars based on the outside air temperature (degC). You decide that a Linear Regression model might be a good candidate to solve this problem.
# Data set:
# - Independant variable X: Outside Air Temperature
# - Dependant variable Y: Overall daily revenue generated in dollars

# %% [markdown]
# ![Data table.png](attachment:61dc2a61-1f26-4f26-ab46-8248d5b39c17.png)

# %% [markdown]
# # Step 1: Libraries Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Step 2: Import Dataset

# %%
IceCream = pd.read_csv("IceCreamData.csv")

# %%
IceCream.head(100)
# Out:
#     Temperature     Revenue
# 0     24.566884  534.799028
# 1     26.005191  625.190122
# 2     27.790554  660.632289
# 3     20.595335  487.706960
# 4     11.503498  316.240194
# ..          ...         ...
# 95     9.018860  212.591740
# 96    20.265012  474.749392
# 97    19.363153  460.402500
# 98    14.685944  343.362905
# 99     9.954357  283.834327
#
# [100 rows x 2 columns]

# %%
IceCream.tail()
# Out:
#      Temperature     Revenue
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
IceCream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
IceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# # Step 3: Visulize Dataset

# %%
sns.jointplot(x='Temperature', y='Revenue', data = IceCream, color = 'gray')

# %%
sns.pairplot(IceCream)

# %%
sns.lmplot(x='Temperature', y='Revenue', data=IceCream)

# %% [markdown]
# # Step 4: Create Testing and Training Dataset

# %%
y = IceCream['Revenue']

# %%
X = IceCream[['Temperature']]

# %%
X
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %% [markdown]
# # Step 5: Train the Model

# %%
X_train.shape
# Out:
# (375, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(fit_intercept = True)

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', regressor.coef_)
print('Linear Model Coefficient (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (m):  [21.52770211]
# Linear Model Coefficient (b):  43.481615241343945

# %% [markdown]
# # Step 6: Test the Model

# %%
y_predict = regressor.predict( X_test)
y_predict
# Out:
# array([ 603.11561834,  514.99252732,  597.29187419,  540.50596335,
#         665.63633358,  670.56480088,  180.23546822,  169.60067373,
#         573.67902684,  367.02385622,  403.07716135,  636.39674616,
#         732.46205254,  311.51944557,  291.12548568,  746.35971595,
#         684.32306294,  523.21677624,  769.91688815,  189.3362385 ,
#         613.01959593,  864.68450379,  702.98938061,  421.81450299,
#         290.08689763,  652.10774389,  470.79015769,  475.11604481,
#         485.05003524,  479.36044505,  331.1845681 ,  264.03416445,
#         456.87743372,  461.83521185,  382.62797343,  450.07880499,
#         311.13853979,  303.15898959,  449.93229477,  570.31684474,
#         510.19998033,  570.76989265,  673.19106859,  600.31593746,
#         639.90787735,  508.70911656,  611.1616702 , 1012.22821029,
#         380.63695333,  742.69695246,  723.32621179,  494.4420563 ,
#         450.00469092,  710.08877351,  635.85176635,  496.13165089,
# ...

# %%
y_test
# Out:
# 166    570.577875
# 303    550.441272
# 314    621.969209
# 342    536.208182
# 461    636.298374
#           ...
# 465    494.627437
# 112    565.875000
# 234    474.832244
# 100    468.975103
# 220    563.301280
# Name: Revenue, Length: 125, dtype: float64

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')

# %%
# VISUALIZE TEST SET RESULTS
plt.scatter(X_test, y_test, color = 'gray')
plt.plot(X_test, regressor.predict(X_test), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Hours')
plt.title('Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')

# %%
print(y_predict)
# Out:
# [ 603.11561834  514.99252732  597.29187419  540.50596335  665.63633358
#   670.56480088  180.23546822  169.60067373  573.67902684  367.02385622
#   403.07716135  636.39674616  732.46205254  311.51944557  291.12548568
#   746.35971595  684.32306294  523.21677624  769.91688815  189.3362385
#   613.01959593  864.68450379  702.98938061  421.81450299  290.08689763
#   652.10774389  470.79015769  475.11604481  485.05003524  479.36044505
#   331.1845681   264.03416445  456.87743372  461.83521185  382.62797343
#   450.07880499  311.13853979  303.15898959  449.93229477  570.31684474
#   510.19998033  570.76989265  673.19106859  600.31593746  639.90787735
#   508.70911656  611.1616702  1012.22821029  380.63695333  742.69695246
#   723.32621179  494.4420563   450.00469092  710.08877351  635.85176635
#   496.13165089  597.13025238  522.44583994  419.25113492  557.60027223
#   663.33215624  715.7699765   623.51622728  311.78001709  470.10769983
# ...

# %%
new_temperature = pd.DataFrame({'Temperature': [30]})
y_predict = regressor.predict(new_temperature)

print(f"Predicted Revenue: ${y_predict[0]:.2f}")
# Out:
# Predicted Revenue: $689.31
